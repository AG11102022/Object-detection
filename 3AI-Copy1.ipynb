# %% [markdown]
# ## Downloading and Storing the test Videos

# %%
video_urls = [
    "https://www.youtube.com/watch?v=DhmZ6W1UAv4",
    "https://www.youtube.com/watch?v=YrydHPwRelI"
]

local_paths = [
    "C:/Users/algba/AI_Assignments/A3/video1.mp4",
    "C:/Users/algba/AI_Assignments/A3/video2.mp4"
]

# %% [markdown]
# ### Function to download videos

# %%
import os
from yt_dlp import YoutubeDL

def download_video(url, local_path):
    ydl_opts = {
        'outtmpl': local_path,
        'format': 'mp4'
    }
    with YoutubeDL(ydl_opts) as ydl:
        ydl.download([url])

for url, path in zip(video_urls, local_paths):
    download_video(url, path)

# %%
for path in local_paths:
    if os.path.exists(path):
        print(f"Video downloaded successfully: {path}")
    else:
        print(f"Failed to download video: {path}")

# %% [markdown]
# ### Split Videos into Frames

# %%
import cv2
import os
import numpy as np

# %%
def split_video_to_frames(video_path, output_dir):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    cap = cv2.VideoCapture(video_path)
    frame_count = 0

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        frame_path = os.path.join(output_dir, f"frame_{frame_count:04d}.png")
        cv2.imwrite(frame_path, frame)
        frame_count += 1

    cap.release()
    print(f"Extracted {frame_count} frames from {video_path}")

video_paths = [
    "C:/Users/algba/AI_Assignments/A3/video1.mp4",
    "C:/Users/algba/AI_Assignments/A3/video2.mp4"
]

for video_path in video_paths:
    output_dir = os.path.splitext(video_path)[0] + "_frames"
    split_video_to_frames(video_path, output_dir)

# %% [markdown]
# ### Preprocess Frames
# ##### Video 2 had a lot of frames to preprocess and I ran out of memory to continue. So just focusing on Video 1 but code will take any other video

# %%
def preprocess_frames(input_dir, output_file):
    frame_files = [f for f in os.listdir(input_dir) if f.endswith('.png')]
    frame_files.sort()

    processed_frames = []
    for frame_file in frame_files:
        frame_path = os.path.join(input_dir, frame_file)
        frame = cv2.imread(frame_path)

        # Resize frame
        resized_frame = cv2.resize(frame, (224, 224))

        # Convert color from BGR to RGB
        rgb_frame = cv2.cvtColor(resized_frame, cv2.COLOR_BGR2RGB)

        # Normalize the frame
        normalized_frame = rgb_frame / 255.0

        processed_frames.append(normalized_frame)

    # Save processed frames to a .npy file
    np.save(output_file, np.array(processed_frames))
    print(f"Saved processed frames to {output_file}")

for video_path in video_paths:
    input_dir = os.path.splitext(video_path)[0] + "_frames"
    output_file = os.path.splitext(video_path)[0] + "_frames.npy"
    preprocess_frames(input_dir, output_file)

# %% [markdown]
# ## Detect Drone in Frames

# %%
# Importing pre-trained YOLO model
import torch
import torchvision.transforms as T
from PIL import Image
import numpy as np
import os
import cv2

# %% [markdown]
# ### Creating virtual environment (I was having issues with some modules that I had to update for other stuff)

# %%
cd C:/Users/algba/AI_Assignments/A3
# Out:
# C:\Users\algba\AI_Assignments\A3

# %%
# !virtualenv venv
# Out:
# created virtual environment CPython3.9.13.final.0-64 in 2415ms
#   creator CPython3Windows(dest=C:\Users\algba\AI_Assignments\A3\venv, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, wheel=bundle, via=copy, app_data_dir=C:\Users\algba\AppData\Local\pypa\virtualenv)
#     added seed packages: pip==24.1, setuptools==70.1.0, wheel==0.43.0
#   activators BashActivator,BatchActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...

# %%
import torch

model = torch.hub.load('./yolov5', 'yolov5s', source='local')  # Load model from local clone
# Out:
# YOLOv5  v7.0-338-gff063284 Python-3.9.13 torch-2.2.1+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %% [markdown]
# ### Detecting objects in frames

# %%
import os
import numpy as np
import cv2
from PIL import Image
from torchvision import transforms as T

# Initialize YOLO model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True).to(device)

def detect_objects_in_frames(input_file, output_dir):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    frames = np.load(input_file)
    transform = T.ToTensor()
    total_frames = len(frames)
    print(f"Total frames to process: {total_frames}")

    for i, frame in enumerate(frames):
        print(f"Processing frame {i+1}/{total_frames}")
        frame = (frame * 255).astype(np.uint8)
        frame_pil = Image.fromarray(frame)
        frame_tensor = transform(frame_pil).unsqueeze(0).to(device)

        # object detection
        results = model(frame_tensor)

        # Numpy array 
        results_np = results[0].detach().cpu().numpy()

        # Checking for drone detections
        detections_found = False
        for det in results_np:
            x1, y1, x2, y2, confidence, class_id = det[:6]
            if confidence > 0.3 and int(class_id) == 0:  # Assuming class 0 is for drone
                detections_found = True
                detection_path = os.path.join(output_dir, f"detection_{i:04d}.png")
                frame_with_detections = frame.copy()

                cv2.rectangle(frame_with_detections, 
                              (int(x1), int(y1)), 
                              (int(x2), int(y2)), 
                              (0, 255, 0), 2)

                cv2.imwrite(detection_path, cv2.cvtColor(frame_with_detections, cv2.COLOR_RGB2BGR))
                print(f"Detected drone in frame {i+1} with confidence {confidence}, bbox: {int(x1), int(y1), int(x2), int(y2)}")

        if not detections_found:
            print(f"No detections in frame {i+1}")

    print("Processing completed.")

# Process the frames from the first video
input_file = "C:/Users/algba/AI_Assignments/A3/video1_frames.npy"
output_dir = "C:/Users/algba/AI_Assignments/A3/video1_detections"
detect_objects_in_frames(input_file, output_dir)
# Out:
# Using cache found in C:\Users\algba/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2024-7-10 Python-3.9.13 torch-2.2.1+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...
# Total frames to process: 4941
# Processing frame 1/4941
# Detected drone in frame 1 with confidence 0.46178361773490906, bbox: (102, 42, 7, 9)
# Detected drone in frame 1 with confidence 0.5888111591339111, bbox: (102, 41, 8, 10)
# Detected drone in frame 1 with confidence 0.608321487903595, bbox: (102, 41, 7, 10)
# Detected drone in frame 1 with confidence 0.382612019777298, bbox: (102, 42, 8, 10)
# Detected drone in frame 1 with confidence 0.5307198762893677, bbox: (103, 41, 8, 10)
# Detected drone in frame 1 with confidence 0.5322533249855042, bbox: (102, 42, 8, 10)
# Detected drone in frame 1 with confidence 0.34522736072540283, bbox: (103, 41, 9, 10)
# Detected drone in frame 1 with confidence 0.3086092472076416, bbox: (102, 42, 9, 10)
# Processing frame 2/4941
# Detected drone in frame 2 with confidence 0.46178361773490906, bbox: (102, 42, 7, 9)
# Detected drone in frame 2 with confidence 0.5888111591339111, bbox: (102, 41, 8, 10)
# Detected drone in frame 2 with confidence 0.608321487903595, bbox: (102, 41, 7, 10)
# Detected drone in frame 2 with confidence 0.382612019777298, bbox: (102, 42, 8, 10)
# Detected drone in frame 2 with confidence 0.5307198762893677, bbox: (103, 41, 8, 10)
# Detected drone in frame 2 with confidence 0.5322533249855042, bbox: (102, 42, 8, 10)
# Detected drone in frame 2 with confidence 0.34522736072540283, bbox: (103, 41, 9, 10)
# Detected drone in frame 2 with confidence 0.3086092472076416, bbox: (102, 42, 9, 10)
# Processing frame 80/4941
# Detected drone in frame 80 with confidence 0.5547612905502319, bbox: (101, 47, 7, 10)
# Detected drone in frame 80 with confidence 0.41493192315101624, bbox: (101, 47, 8, 10)
# Detected drone in frame 80 with confidence 0.5756617784500122, bbox: (101, 47, 7, 10)
# Detected drone in frame 80 with confidence 0.4643539488315582, bbox: (101, 47, 7, 10)
# Detected drone in frame 80 with confidence 0.3672730326652527, bbox: (101, 47, 8, 10)
# Detected drone in frame 80 with confidence 0.5534095168113708, bbox: (101, 47, 7, 10)
# Processing frame 81/4941
# Detected drone in frame 81 with confidence 0.5588682293891907, bbox: (101, 47, 7, 10)
# Detected drone in frame 81 with confidence 0.37960126996040344, bbox: (101, 47, 8, 10)
# Detected drone in frame 81 with confidence 0.5835621356964111, bbox: (101, 47, 8, 10)
# Detected drone in frame 81 with confidence 0.4931778609752655, bbox: (101, 47, 7, 10)
# Detected drone in frame 81 with confidence 0.34056785702705383, bbox: (101, 47, 8, 11)
# Detected drone in frame 81 with confidence 0.5718023180961609, bbox: (101, 47, 8, 11)
# Detected drone in frame 81 with confidence 0.32070574164390564, bbox: (101, 47, 9, 11)
# Processing frame 82/4941
# Detected drone in frame 82 with confidence 0.5586144328117371, bbox: (101, 47, 7, 10)
# Detected drone in frame 82 with confidence 0.37257036566734314, bbox: (101, 47, 8, 10)
# Detected drone in frame 82 with confidence 0.5829427242279053, bbox: (101, 47, 7, 10)
# Detected drone in frame 82 with confidence 0.4929770529270172, bbox: (101, 47, 7, 10)
# Detected drone in frame 82 with confidence 0.3305753171443939, bbox: (101, 47, 8, 11)
# Detected drone in frame 82 with confidence 0.5688058137893677, bbox: (101, 47, 7, 11)
# Processing frame 83/4941
# Detected drone in frame 83 with confidence 0.5312227606773376, bbox: (101, 47, 7, 10)
# Detected drone in frame 83 with confidence 0.34207791090011597, bbox: (101, 47, 8, 10)
# Detected drone in frame 83 with confidence 0.5577256083488464, bbox: (101, 47, 7, 10)
# Detected drone in frame 83 with confidence 0.44760268926620483, bbox: (101, 47, 7, 10)
# Detected drone in frame 83 with confidence 0.5396210551261902, bbox: (101, 47, 7, 10)
# Processing frame 84/4941
# Detected drone in frame 84 with confidence 0.5152716636657715, bbox: (101, 47, 7, 10)
# Detected drone in frame 84 with confidence 0.33740565180778503, bbox: (101, 47, 8, 10)
# Detected drone in frame 84 with confidence 0.5460872650146484, bbox: (101, 47, 7, 10)
# ...
# No detections in frame 4651
# Processing frame 4652/4941
# No detections in frame 4652
# Processing frame 4653/4941
# No detections in frame 4653
# Processing frame 4654/4941
# No detections in frame 4654
# Processing frame 4655/4941
# No detections in frame 4655
# Processing frame 4656/4941
# No detections in frame 4656
# Processing frame 4657/4941
# No detections in frame 4657
# Processing frame 4658/4941
# No detections in frame 4658
# Processing frame 4659/4941
# No detections in frame 4659
# Processing frame 4660/4941
# No detections in frame 4660
# Processing frame 4661/4941
# No detections in frame 4661
# Processing frame 4662/4941
# No detections in frame 4662
# Processing frame 4663/4941
# No detections in frame 4663
# Processing frame 4664/4941
# No detections in frame 4664
# Processing frame 4665/4941
# No detections in frame 4665
# Processing frame 4666/4941
# No detections in frame 4666
# Processing frame 4667/4941
# No detections in frame 4667
# Processing frame 4668/4941
# No detections in frame 4668
# Processing frame 4669/4941
# No detections in frame 4669
# Processing frame 4670/4941
# No detections in frame 4670
# Processing frame 4671/4941
# No detections in frame 4671
# Processing frame 4672/4941
# No detections in frame 4672
# Processing frame 4673/4941
# No detections in frame 4673
# Processing frame 4674/4941
# No detections in frame 4674
# Processing frame 4675/4941
# No detections in frame 4675
# Processing frame 4676/4941
# No detections in frame 4676
# Processing frame 4677/4941
# No detections in frame 4677
# Processing frame 4678/4941
# No detections in frame 4678
# Processing frame 4679/4941
# No detections in frame 4679
# Processing frame 4680/4941
# No detections in frame 4680
# Processing frame 4681/4941
# No detections in frame 4681
# Processing frame 4682/4941
# No detections in frame 4682
# Processing frame 4683/4941
# No detections in frame 4683
# Processing frame 4684/4941
# No detections in frame 4684
# Processing frame 4685/4941
# No detections in frame 4685
# Processing frame 4686/4941
# No detections in frame 4686
# Processing frame 4687/4941
# No detections in frame 4687
# Processing frame 4688/4941
# No detections in frame 4688
# Processing frame 4689/4941
# No detections in frame 4689
# Processing frame 4690/4941
# No detections in frame 4690
# Processing frame 4691/4941
# No detections in frame 4691
# Processing frame 4692/4941
# No detections in frame 4692
# Processing frame 4693/4941
# No detections in frame 4693
# Processing frame 4694/4941
# No detections in frame 4694
# Processing frame 4695/4941
# No detections in frame 4695
# Processing frame 4696/4941
# No detections in frame 4696
# Processing frame 4697/4941
# No detections in frame 4697
# Processing frame 4698/4941
# No detections in frame 4698
# Processing frame 4699/4941
# No detections in frame 4699
# Processing frame 4700/4941
# No detections in frame 4700
# Processing frame 4701/4941
# No detections in frame 4701
# Processing frame 4702/4941
# No detections in frame 4702
# Processing frame 4703/4941
# No detections in frame 4703
# Processing frame 4704/4941
# No detections in frame 4704
# Processing frame 4705/4941
# No detections in frame 4705
# Processing frame 4706/4941
# No detections in frame 4706
# Processing frame 4707/4941
# No detections in frame 4707
# Processing frame 4708/4941
# No detections in frame 4708
# Processing frame 4709/4941
# No detections in frame 4709
# Processing frame 4710/4941
# No detections in frame 4710
# Processing frame 4711/4941
# No detections in frame 4711
# Processing frame 4712/4941
# No detections in frame 4712
# Processing frame 4713/4941
# No detections in frame 4713
# Processing frame 4714/4941
# No detections in frame 4714
# Processing frame 4715/4941
# No detections in frame 4715
# Processing frame 4716/4941
# No detections in frame 4716
# Processing frame 4717/4941
# No detections in frame 4717
# Processing frame 4718/4941
# No detections in frame 4718
# Processing frame 4719/4941
# No detections in frame 4719
# Processing frame 4720/4941
# No detections in frame 4720
# Processing frame 4721/4941
# No detections in frame 4721
# Processing frame 4722/4941
# No detections in frame 4722
# Processing frame 4723/4941
# No detections in frame 4723
# Processing frame 4724/4941
# No detections in frame 4724
# Processing frame 4725/4941
# No detections in frame 4725
# Processing frame 4726/4941
# No detections in frame 4726
# Processing frame 4727/4941
# No detections in frame 4727
# Processing frame 4728/4941
# No detections in frame 4728
# Processing frame 4729/4941
# No detections in frame 4729
# Processing frame 4730/4941
# No detections in frame 4730
# Processing frame 4731/4941
# No detections in frame 4731
# Processing frame 4732/4941
# No detections in frame 4732
# Processing frame 4733/4941
# No detections in frame 4733
# Processing frame 4734/4941
# No detections in frame 4734
# Processing frame 4735/4941
# No detections in frame 4735
# Processing frame 4736/4941
# No detections in frame 4736
# Processing frame 4737/4941
# No detections in frame 4737
# Processing frame 4738/4941
# No detections in frame 4738
# Processing frame 4739/4941
# No detections in frame 4739
# Processing frame 4740/4941
# No detections in frame 4740
# Processing frame 4741/4941
# No detections in frame 4741
# Processing frame 4742/4941
# No detections in frame 4742
# Processing frame 4743/4941
# No detections in frame 4743
# Processing frame 4744/4941
# No detections in frame 4744
# Processing frame 4745/4941
# No detections in frame 4745
# Processing frame 4746/4941
# No detections in frame 4746
# Processing frame 4747/4941
# No detections in frame 4747
# Processing frame 4748/4941
# No detections in frame 4748
# Processing frame 4749/4941
# No detections in frame 4749
# Processing frame 4750/4941
# No detections in frame 4750
# Processing frame 4751/4941
# No detections in frame 4751
# Processing frame 4752/4941
# No detections in frame 4752
# Processing frame 4753/4941
# No detections in frame 4753
# Processing frame 4754/4941
# No detections in frame 4754
# Processing frame 4755/4941
# No detections in frame 4755
# Processing frame 4756/4941
# No detections in frame 4756
# Processing frame 4757/4941
# No detections in frame 4757
# Processing frame 4758/4941
# No detections in frame 4758
# Processing frame 4759/4941
# No detections in frame 4759
# Processing frame 4760/4941
# No detections in frame 4760
# Processing frame 4761/4941
# No detections in frame 4761
# Processing frame 4762/4941
# No detections in frame 4762
# Processing frame 4763/4941
# No detections in frame 4763
# Processing frame 4764/4941
# No detections in frame 4764
# Processing frame 4765/4941
# No detections in frame 4765
# Processing frame 4766/4941
# No detections in frame 4766
# Processing frame 4767/4941
# No detections in frame 4767
# Processing frame 4768/4941
# No detections in frame 4768
# Processing frame 4769/4941
# No detections in frame 4769
# Processing frame 4770/4941
# No detections in frame 4770
# Processing frame 4771/4941
# No detections in frame 4771
# Processing frame 4772/4941
# No detections in frame 4772
# Processing frame 4773/4941
# No detections in frame 4773
# Processing frame 4774/4941
# No detections in frame 4774
# Processing frame 4775/4941
# No detections in frame 4775
# Processing frame 4776/4941
# No detections in frame 4776
# Processing frame 4777/4941
# No detections in frame 4777
# Processing frame 4778/4941
# No detections in frame 4778
# Processing frame 4779/4941
# No detections in frame 4779
# Processing frame 4780/4941
# No detections in frame 4780
# Processing frame 4781/4941
# No detections in frame 4781
# Processing frame 4782/4941
# No detections in frame 4782
# Processing frame 4783/4941
# No detections in frame 4783
# Processing frame 4784/4941
# No detections in frame 4784
# Processing frame 4785/4941
# No detections in frame 4785
# Processing frame 4786/4941
# No detections in frame 4786
# Processing frame 4787/4941
# No detections in frame 4787
# Processing frame 4788/4941
# No detections in frame 4788
# Processing frame 4789/4941
# No detections in frame 4789
# Processing frame 4790/4941
# No detections in frame 4790
# Processing frame 4791/4941
# No detections in frame 4791
# Processing frame 4792/4941
# No detections in frame 4792
# Processing frame 4793/4941
# No detections in frame 4793
# Processing frame 4794/4941
# No detections in frame 4794
# Processing frame 4795/4941
# No detections in frame 4795
# Processing frame 4796/4941
# No detections in frame 4796
# Processing frame 4797/4941
# No detections in frame 4797
# Processing frame 4798/4941
# No detections in frame 4798
# Processing frame 4799/4941
# No detections in frame 4799
# Processing frame 4800/4941
# No detections in frame 4800
# Processing frame 4801/4941
# No detections in frame 4801
# Processing frame 4802/4941
# No detections in frame 4802
# Processing frame 4803/4941
# No detections in frame 4803
# Processing frame 4804/4941
# No detections in frame 4804
# Processing frame 4805/4941
# No detections in frame 4805
# Processing frame 4806/4941
# No detections in frame 4806
# Processing frame 4807/4941
# No detections in frame 4807
# Processing frame 4808/4941
# No detections in frame 4808
# Processing frame 4809/4941
# No detections in frame 4809
# Processing frame 4810/4941
# No detections in frame 4810
# Processing frame 4811/4941
# No detections in frame 4811
# Processing frame 4812/4941
# No detections in frame 4812
# Processing frame 4813/4941
# No detections in frame 4813
# Processing frame 4814/4941
# No detections in frame 4814
# Processing frame 4815/4941
# No detections in frame 4815
# Processing frame 4816/4941
# No detections in frame 4816
# Processing frame 4817/4941
# No detections in frame 4817
# Processing frame 4818/4941
# No detections in frame 4818
# Processing frame 4819/4941
# No detections in frame 4819
# Processing frame 4820/4941
# No detections in frame 4820
# Processing frame 4821/4941
# No detections in frame 4821
# Processing frame 4822/4941
# No detections in frame 4822
# Processing frame 4823/4941
# No detections in frame 4823
# Processing frame 4824/4941
# No detections in frame 4824
# Processing frame 4825/4941
# No detections in frame 4825
# Processing frame 4826/4941
# No detections in frame 4826
# Processing frame 4827/4941
# No detections in frame 4827
# Processing frame 4828/4941
# No detections in frame 4828
# Processing frame 4829/4941
# No detections in frame 4829
# Processing frame 4830/4941
# No detections in frame 4830
# Processing frame 4831/4941
# No detections in frame 4831
# Processing frame 4832/4941
# No detections in frame 4832
# Processing frame 4833/4941
# No detections in frame 4833
# Processing frame 4834/4941
# No detections in frame 4834
# Processing frame 4835/4941
# No detections in frame 4835
# Processing frame 4836/4941
# No detections in frame 4836
# Processing frame 4837/4941
# No detections in frame 4837
# Processing frame 4838/4941
# No detections in frame 4838
# Processing frame 4839/4941
# No detections in frame 4839
# Processing frame 4840/4941
# No detections in frame 4840
# Processing frame 4841/4941
# No detections in frame 4841
# Processing frame 4842/4941
# No detections in frame 4842
# Processing frame 4843/4941
# No detections in frame 4843
# Processing frame 4844/4941
# No detections in frame 4844
# Processing frame 4845/4941
# No detections in frame 4845
# Processing frame 4846/4941
# No detections in frame 4846
# Processing frame 4847/4941
# No detections in frame 4847
# Processing frame 4848/4941
# No detections in frame 4848
# Processing frame 4849/4941
# No detections in frame 4849
# Processing frame 4850/4941
# No detections in frame 4850
# Processing frame 4851/4941
# No detections in frame 4851
# Processing frame 4852/4941
# No detections in frame 4852
# Processing frame 4853/4941
# No detections in frame 4853
# Processing frame 4854/4941
# No detections in frame 4854
# Processing frame 4855/4941
# No detections in frame 4855
# Processing frame 4856/4941
# No detections in frame 4856
# Processing frame 4857/4941
# No detections in frame 4857
# Processing frame 4858/4941
# No detections in frame 4858
# Processing frame 4859/4941
# No detections in frame 4859
# Processing frame 4860/4941
# No detections in frame 4860
# Processing frame 4861/4941
# No detections in frame 4861
# Processing frame 4862/4941
# No detections in frame 4862
# Processing frame 4863/4941
# No detections in frame 4863
# Processing frame 4864/4941
# No detections in frame 4864
# Processing frame 4865/4941
# No detections in frame 4865
# Processing frame 4866/4941
# No detections in frame 4866
# Processing frame 4867/4941
# No detections in frame 4867
# Processing frame 4868/4941
# No detections in frame 4868
# Processing frame 4869/4941
# No detections in frame 4869
# Processing frame 4870/4941
# No detections in frame 4870
# Processing frame 4871/4941
# No detections in frame 4871
# Processing frame 4872/4941
# No detections in frame 4872
# Processing frame 4873/4941
# No detections in frame 4873
# Processing frame 4874/4941
# No detections in frame 4874
# Processing frame 4875/4941
# No detections in frame 4875
# Processing frame 4876/4941
# No detections in frame 4876
# Processing frame 4877/4941
# No detections in frame 4877
# Processing frame 4878/4941
# No detections in frame 4878
# Processing frame 4879/4941
# No detections in frame 4879
# Processing frame 4880/4941
# No detections in frame 4880
# Processing frame 4881/4941
# No detections in frame 4881
# Processing frame 4882/4941
# No detections in frame 4882
# Processing frame 4883/4941
# No detections in frame 4883
# Processing frame 4884/4941
# No detections in frame 4884
# Processing frame 4885/4941
# No detections in frame 4885
# Processing frame 4886/4941
# No detections in frame 4886
# Processing frame 4887/4941
# No detections in frame 4887
# Processing frame 4888/4941
# No detections in frame 4888
# Processing frame 4889/4941
# No detections in frame 4889
# Processing frame 4890/4941
# No detections in frame 4890
# Processing frame 4891/4941
# No detections in frame 4891
# Processing frame 4892/4941
# No detections in frame 4892
# Processing frame 4893/4941
# No detections in frame 4893
# Processing frame 4894/4941
# No detections in frame 4894
# Processing frame 4895/4941
# No detections in frame 4895
# Processing frame 4896/4941
# No detections in frame 4896
# Processing frame 4897/4941
# No detections in frame 4897
# Processing frame 4898/4941
# No detections in frame 4898
# Processing frame 4899/4941
# No detections in frame 4899
# Processing frame 4900/4941
# No detections in frame 4900
# Processing frame 4901/4941
# No detections in frame 4901
# Processing frame 4902/4941
# No detections in frame 4902
# Processing frame 4903/4941
# No detections in frame 4903
# Processing frame 4904/4941
# No detections in frame 4904
# Processing frame 4905/4941
# No detections in frame 4905
# Processing frame 4906/4941
# No detections in frame 4906
# Processing frame 4907/4941
# No detections in frame 4907
# Processing frame 4908/4941
# No detections in frame 4908
# Processing frame 4909/4941
# No detections in frame 4909
# Processing frame 4910/4941
# No detections in frame 4910
# Processing frame 4911/4941
# No detections in frame 4911
# Processing frame 4912/4941
# No detections in frame 4912
# Processing frame 4913/4941
# No detections in frame 4913
# Processing frame 4914/4941
# No detections in frame 4914
# Processing frame 4915/4941
# No detections in frame 4915
# Processing frame 4916/4941
# No detections in frame 4916
# Processing frame 4917/4941
# No detections in frame 4917
# Processing frame 4918/4941
# No detections in frame 4918
# Processing frame 4919/4941
# No detections in frame 4919
# Processing frame 4920/4941
# No detections in frame 4920
# Processing frame 4921/4941
# No detections in frame 4921
# Processing frame 4922/4941
# No detections in frame 4922
# Processing frame 4923/4941
# No detections in frame 4923
# Processing frame 4924/4941
# No detections in frame 4924
# Processing frame 4925/4941
# No detections in frame 4925
# Processing frame 4926/4941
# No detections in frame 4926
# Processing frame 4927/4941
# No detections in frame 4927
# Processing frame 4928/4941
# No detections in frame 4928
# Processing frame 4929/4941
# No detections in frame 4929
# Processing frame 4930/4941
# No detections in frame 4930
# Processing frame 4931/4941
# No detections in frame 4931
# Processing frame 4932/4941
# No detections in frame 4932
# Processing frame 4933/4941
# No detections in frame 4933
# Processing frame 4934/4941
# No detections in frame 4934
# Processing frame 4935/4941
# No detections in frame 4935
# Processing frame 4936/4941
# No detections in frame 4936
# Processing frame 4937/4941
# No detections in frame 4937
# Processing frame 4938/4941
# No detections in frame 4938
# Processing frame 4939/4941
# No detections in frame 4939
# Processing frame 4940/4941
# No detections in frame 4940
# Processing frame 4941/4941
# No detections in frame 4941
# Processing completed.

# %% [markdown]
# ### kalman Fiter for Object Tracking

# %%
import cv2
from filterpy.kalman import KalmanFilter
import numpy as np
import torch

# Initialize Kalman Filter
kf = KalmanFilter(dim_x=4, dim_z=2)  # 2D state (x, y, dx, dy)

# Initial coordinates based on detection
initial_x = 100
initial_y = 100

kf.x = np.array([initial_x, initial_y, 0., 0.])  # initial state: position and velocity
kf.F = np.array([[1, 0, 1, 0],
                 [0, 1, 0, 1],
                 [0, 0, 1, 0],
                 [0, 0, 0, 1]])  # state transition matrix

# Measurement matrix
kf.H = np.array([[1, 0, 0, 0],
                 [0, 1, 0, 0]])

# Measurement noise covariance
kf.R = np.eye(2) * 0.5

# Noise covariance
kf.Q = np.eye(4) * 0.1

# Loading YOLO model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)

# Loading video
video_path = "C:/Users/algba/AI_Assignments/A3/video1.mp4"
cap = cv2.VideoCapture(video_path)
if not cap.isOpened():
    print(f"Error opening video file at {video_path}")
    exit()

# Output video settings
output_path = "C:/Users/algba/AI_Assignments/A3/tracked_video1.mp4"
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)
out = cv2.VideoWriter(output_path, cv2.VideoWriter_fourcc(*'mp4v'), fps, (frame_width, frame_height))

if not out.isOpened():
    print(f"Error opening output video file at {output_path}")
    exit()

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    
    # Performing detection of drone position using YOLO
    results = model(frame)
    detections = results.xyxy[0].cpu().numpy()
    
    # Finding the largest detection (drone)
    if len(detections) > 0:
        detection = max(detections, key=lambda x: x[4])  # x[4] is the confidence score
        x1, y1, x2, y2, confidence, class_id = detection
        detected_x = (x1 + x2) / 2
        detected_y = (y1 + y2) / 2
        
        # Updating Kalman filter with detected position
        kf.predict()
        kf.update([detected_x, detected_y])
        
        # Estimating state from Kalman filter
        estimated_x = int(kf.x[0])
        estimated_y = int(kf.x[1])
        estimated_dx = int(kf.x[2])
        estimated_dy = int(kf.x[3])
        
        # Calculating predicted next position based on estimated velocity
        predicted_x = estimated_x + estimated_dx
        predicted_y = estimated_y + estimated_dy
        
        # Updating bounding box coordinates based on predicted position
        bbox_x1 = predicted_x - 50
        bbox_y1 = predicted_y - 50
        bbox_x2 = predicted_x + 50
        bbox_y2 = predicted_y + 50
        
        # Drawing green rectangle based on updated bounding box coordinates
        cv2.rectangle(frame, (bbox_x1, bbox_y1), (bbox_x2, bbox_y2), (0, 255, 0), 2)
        
    # Writing the frame into the output video
    out.write(frame)
    
    cv2.imshow('Tracked Video Frame', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Model summary
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# Using cache found in C:\Users\algba/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2024-7-10 Python-3.9.13 torch-2.2.1+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...
